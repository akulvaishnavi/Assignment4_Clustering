# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!") # Installing Pycaret
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
import pandas as pd

# %%
from pycaret.datasets import get_data
dataSets = get_data('index') # List of datasets in Pycaret
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
dataset = get_data("iris")
# This is unsupervised dataset.
# No target is defined.
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
dataset.to_csv("irisDataSet.csv")
from google.colab import files # Downloading dataset to local system

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(dataset)
# Out:
# <style type="text/css">
# #T_49528_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_49528" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49528_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_49528_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49528_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49528_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_49528_row0_col1" class="data row0 col1" >514</td>
#     </tr>
#     <tr>
#       <th id="T_49528_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49528_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_49528_row1_col1" class="data row1 col1" >(150, 5)</td>
#     </tr>
#     <tr>
# ...

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4) # Make Clustering Model
# Out:
# <style type="text/css">
# </style>
# <table id="T_14a64" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14a64_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_14a64_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_14a64_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_14a64_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_14a64_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_14a64_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14a64_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14a64_row0_col0" class="data row0 col0" >0.5785</td>
#       <td id="T_14a64_row0_col1" class="data row0 col1" >514.0075</td>
# ...

# %%
kMeanPrediction = assign_model(KMeanClusteringModel) # Assign labels to the Dataset
kMeanPrediction
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#        Cluster
# 0    Cluster 1
# 1    Cluster 1
# 2    Cluster 1
# ...

# %%
from pycaret.clustering import *

kMeanClusteringParameters = setup(dataset, verbose=False)
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction # Clustering in 3 lines of code
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b857" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b857_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6b857_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6b857_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6b857_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6b857_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6b857_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b857_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b857_row0_col0" class="data row0 col0" >0.5785</td>
#       <td id="T_6b857_row0_col1" class="data row0 col1" >514.0075</td>
# ...

# %%
kMeanPrediction.to_csv("KMeanResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
# Download the result file to user local system

from google.colab import files
#files.download('KMeanResult.csv')      # Uncomment this line

# %%
x = save_model(KMeanClusteringModel, 'kMeanClusteringModelFile') # Save the trained model
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
from google.colab import files # Download the trained model
#files.download('kMeanClusteringModelFile.pkl')      # Uncomment this line

# %%
from google.colab import files # Upload the trained model
#files.upload()                     # Uncomment this line

# %%
#KMeanClusteringModel1 = load_model('kMeanClusteringModelFile (1)')  # Load the trained model

# %% [markdown]
# <h> Clustering without Pre-processing (K-Means) </h>

# %%
newData = get_data("iris").iloc[:10]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
newPredictions = predict_model(KMeanClusteringModel, data = newData) # Make prediction on unseen dataset
newPredictions
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species_Iris-setosa  \
# 0           5.1          3.5           1.4          0.2                  1.0
# 1           4.9          3.0           1.4          0.2                  1.0
# 2           4.7          3.2           1.3          0.2                  1.0
# 3           4.6          3.1           1.5          0.2                  1.0
# 4           5.0          3.6           1.4          0.2                  1.0
# 5           5.4          3.9           1.7          0.4                  1.0
# 6           4.6          3.4           1.4          0.3                  1.0
# 7           5.0          3.4           1.5          0.2                  1.0
# 8           4.4          2.9           1.4          0.2                  1.0
# 9           4.9          3.1           1.5          0.1                  1.0
#
#    species_Iris-versicolor  species_Iris-virginica    Cluster
# ...

# %%
newPredictions.to_csv("NewPredictions.csv") # Save prediction result
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
evaluate_model(KMeanClusteringModel) # Evaluate Cluster Model
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(KMeanClusteringModel, plot = 'tsne') # 3D Plot for Cluster
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(KMeanClusteringModel, plot = 'elbow')  # Elbow plot

# %%
plot_model(KMeanClusteringModel, plot = 'silhouette')  # Silhouette plot

# %% [markdown]
# Check for Clusters 3,4,5,6 for Iris dataset

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

dataset = get_data('iris', verbose=False)
setup(data = dataset, verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e4889" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4889_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e4889_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e4889_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e4889_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e4889_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e4889_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4889_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4889_row0_col0" class="data row0 col0" >0.6223</td>
#       <td id="T_e4889_row0_col1" class="data row0 col1" >576.5206</td>
# ...

# %% [markdown]
# Model Performance using "Normalization"

# %%
setup(data = dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow') # Elbow plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_52112" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52112_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_52112_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_52112_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_52112_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_52112_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_52112_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52112_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52112_row0_col0" class="data row0 col0" >0.5699</td>
#       <td id="T_52112_row0_col1" class="data row0 col1" >321.2588</td>
# ...

# %% [markdown]
# Check for Clusters 3,4,5,6

# %%
setup(data = dataset, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c3762" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3762_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c3762_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c3762_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c3762_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c3762_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c3762_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3762_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3762_row0_col0" class="data row0 col0" >0.6563</td>
#       <td id="T_c3762_row0_col1" class="data row0 col1" >386.1793</td>
# ...

# %%
setup(data = dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans', num_clusters = 3)
plot_model(x, plot = 'tsne') # 3D plot for Clusters = 3
# Out:
# <style type="text/css">
# </style>
# <table id="T_04dee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04dee_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_04dee_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_04dee_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_04dee_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_04dee_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_04dee_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04dee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04dee_row0_col0" class="data row0 col0" >0.6563</td>
#       <td id="T_04dee_row0_col1" class="data row0 col1" >386.1793</td>
# ...

# %% [markdown]
# Model Performance using 'Transformation'

# %%
setup(data = dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow') # Elbow Plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_5ba9d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ba9d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5ba9d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5ba9d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5ba9d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5ba9d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5ba9d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ba9d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ba9d_row0_col0" class="data row0 col0" >0.6051</td>
#       <td id="T_5ba9d_row0_col1" class="data row0 col1" >1273.3866</td>
# ...

# %% [markdown]
# Check for clusters 3,4,5,6

# %%
setup(data = dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c3db2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3db2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c3db2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c3db2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c3db2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c3db2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c3db2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3db2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3db2_row0_col0" class="data row0 col0" >0.6600</td>
#       <td id="T_c3db2_row0_col1" class="data row0 col1" >1153.7177</td>
# ...

# %% [markdown]
# Model Performance using 'PCA'

# %%
setup(data = dataset, pca = True, pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow') # Elbow plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_95481" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95481_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_95481_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_95481_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_95481_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_95481_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_95481_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95481_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95481_row0_col0" class="data row0 col0" >0.5785</td>
#       <td id="T_95481_row0_col1" class="data row0 col1" >514.0075</td>
# ...

# %% [markdown]
# Check for Clusters 3,4,5,6

# %%
setup(data = dataset, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_f96e1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f96e1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f96e1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f96e1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f96e1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f96e1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f96e1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f96e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f96e1_row0_col0" class="data row0 col0" >0.6223</td>
#       <td id="T_f96e1_row0_col1" class="data row0 col1" >576.5206</td>
# ...

# %% [markdown]
# Model Performance using "Transformation" + "Normalization"

# %%
setup(data = dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_308ce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_308ce_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_308ce_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_308ce_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_308ce_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_308ce_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_308ce_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_308ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_308ce_row0_col0" class="data row0 col0" >0.5787</td>
#       <td id="T_308ce_row0_col1" class="data row0 col1" >327.1575</td>
# ...

# %% [markdown]
# Check for Clusters 3,4,5,6

# %%
setup(data = dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_a83cb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a83cb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a83cb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a83cb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a83cb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a83cb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a83cb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a83cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a83cb_row0_col0" class="data row0 col0" >0.6577</td>
#       <td id="T_a83cb_row0_col1" class="data row0 col1" >391.8238</td>
# ...

# %% [markdown]
# Model Performance using "Transformation" + "Normalization" + "PCA"

# %%
setup(data = dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow') # Elbow plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_9fd80" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fd80_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9fd80_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9fd80_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9fd80_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9fd80_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9fd80_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fd80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fd80_row0_col0" class="data row0 col0" >0.5787</td>
#       <td id="T_9fd80_row0_col1" class="data row0 col1" >327.1575</td>
# ...

# %% [markdown]
# Check for Clusters 3,4,5,6

# %%
setup(data = dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_5aa9a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5aa9a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5aa9a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5aa9a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5aa9a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5aa9a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5aa9a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5aa9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5aa9a_row0_col0" class="data row0 col0" >0.6577</td>
#       <td id="T_5aa9a_row0_col1" class="data row0 col1" >391.8238</td>
# ...

# %% [markdown]
# Hierarchical Clustering

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

dataset = get_data('iris', verbose=False)
setup(data = dataset, verbose=False)

x = create_model('hclust')
plot_model(x, plot = 'elbow') # Elbow Plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_48a9b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48a9b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_48a9b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_48a9b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_48a9b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_48a9b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_48a9b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48a9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48a9b_row0_col0" class="data row0 col0" >0.5865</td>
#       <td id="T_48a9b_row0_col1" class="data row0 col1" >512.1318</td>
# ...

# %%
hierarchicalModel = create_model('hclust', num_clusters=3)
hierarchicalModelPrediction = assign_model(hierarchicalModel) # Assign labels to dataset
hierarchicalModelPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_5b34f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b34f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5b34f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5b34f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5b34f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5b34f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5b34f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b34f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b34f_row0_col0" class="data row0 col0" >0.6216</td>
#       <td id="T_5b34f_row0_col1" class="data row0 col1" >568.5478</td>
# ...

# %% [markdown]
# Clustering for 3,4,5,6 clusters total

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

dataset = get_data('iris', verbose=False)
setup(data = dataset, verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_df8b4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df8b4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_df8b4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_df8b4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_df8b4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_df8b4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_df8b4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df8b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df8b4_row0_col0" class="data row0 col0" >0.6216</td>
#       <td id="T_df8b4_row0_col1" class="data row0 col1" >568.5478</td>
# ...

# %% [markdown]
# HC Using Normalisation

# %%
setup(data = dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow') # Elbow plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_46c75" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46c75_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_46c75_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_46c75_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_46c75_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_46c75_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_46c75_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46c75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46c75_row0_col0" class="data row0 col0" >0.5667</td>
#       <td id="T_46c75_row0_col1" class="data row0 col1" >320.0156</td>
# ...

# %% [markdown]
# Check for Clusters 3,4,5,6

# %%
setup(data = dataset, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_7fb5e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fb5e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7fb5e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7fb5e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7fb5e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7fb5e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7fb5e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fb5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7fb5e_row0_col0" class="data row0 col0" >0.6563</td>
#       <td id="T_7fb5e_row0_col1" class="data row0 col1" >386.1793</td>
# ...

# %% [markdown]
# HC Using Transformation

# %%
setup(data = dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow') # Elbow plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_97a27" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97a27_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_97a27_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_97a27_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_97a27_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_97a27_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_97a27_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97a27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97a27_row0_col0" class="data row0 col0" >0.5893</td>
#       <td id="T_97a27_row0_col1" class="data row0 col1" >1225.1018</td>
# ...

# %% [markdown]
# Check for Clusters 3,4,5,6

# %%
setup(data = dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_8682d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8682d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8682d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8682d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8682d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8682d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8682d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8682d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8682d_row0_col0" class="data row0 col0" >0.6228</td>
#       <td id="T_8682d_row0_col1" class="data row0 col1" >909.3446</td>
# ...

# %% [markdown]
# HC Using PCA

# %%
setup(data = dataset, pca = True, pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow') # Elbow plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_504e6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_504e6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_504e6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_504e6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_504e6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_504e6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_504e6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_504e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_504e6_row0_col0" class="data row0 col0" >0.5865</td>
#       <td id="T_504e6_row0_col1" class="data row0 col1" >512.1318</td>
# ...

# %% [markdown]
# Check for Clusters 3,4,5,6

# %%
setup(data = dataset, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_8bf5a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bf5a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8bf5a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8bf5a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8bf5a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8bf5a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8bf5a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bf5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8bf5a_row0_col0" class="data row0 col0" >0.6216</td>
#       <td id="T_8bf5a_row0_col1" class="data row0 col1" >568.5478</td>
# ...

# %% [markdown]
# HC Using Transformation + Normalisation

# %%
setup(data = dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow') # Elbow plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_12205" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12205_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_12205_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_12205_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_12205_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_12205_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_12205_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12205_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12205_row0_col0" class="data row0 col0" >0.5786</td>
#       <td id="T_12205_row0_col1" class="data row0 col1" >326.7618</td>
# ...

# %% [markdown]
# Check for Clusters 3,4,5,6

# %%
setup(data = dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0a615" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a615_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0a615_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0a615_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0a615_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0a615_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0a615_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a615_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a615_row0_col0" class="data row0 col0" >0.6577</td>
#       <td id="T_0a615_row0_col1" class="data row0 col1" >391.8238</td>
# ...

# %% [markdown]
# HC Using PCA + Transformation + Normalisation

# %%
setup(data = dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow') # Elbow plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_60ee7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60ee7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_60ee7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_60ee7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_60ee7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_60ee7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_60ee7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60ee7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60ee7_row0_col0" class="data row0 col0" >0.5786</td>
#       <td id="T_60ee7_row0_col1" class="data row0 col1" >326.7618</td>
# ...

# %% [markdown]
# Checking for clusters 3,4,5,6

# %%
setup(data = dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_154e0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_154e0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_154e0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_154e0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_154e0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_154e0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_154e0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_154e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_154e0_row0_col0" class="data row0 col0" >0.6577</td>
#       <td id="T_154e0_row0_col1" class="data row0 col1" >391.8238</td>
# ...

# %% [markdown]
# K-Modes Clustering (KMC)

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

dataset = get_data('iris', verbose=False)
setup(data = dataset, verbose=False)

x = create_model('meanshift')
plot_model(x, plot = 'cluster') # Cluster Plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5c18" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5c18_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e5c18_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e5c18_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e5c18_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e5c18_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e5c18_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5c18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5c18_row0_col0" class="data row0 col0" >0.6223</td>
#       <td id="T_e5c18_row0_col1" class="data row0 col1" >576.5206</td>
# ...

# %%
kmeanshiftModel = create_model('meanshift', num_clusters=3) # Assign labels
kmeanshiftModelPrediction = assign_model(kmeanshiftModel)
kmeanshiftModelPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_c83c0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c83c0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c83c0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c83c0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c83c0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c83c0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c83c0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c83c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c83c0_row0_col0" class="data row0 col0" >0.6223</td>
#       <td id="T_c83c0_row0_col1" class="data row0 col1" >576.5206</td>
# ...

# %% [markdown]
# Check for Clusters 3,4,5,6

# %%
setup(data = dataset, verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)

print("For Cluster = 6")
x = create_model('meanshift', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_ec257" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec257_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ec257_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ec257_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ec257_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ec257_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ec257_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec257_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec257_row0_col0" class="data row0 col0" >0.6223</td>
#       <td id="T_ec257_row0_col1" class="data row0 col1" >576.5206</td>
# ...

# %% [markdown]
# KMC using Normalisation

# %%
setup(data = dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('meanshift')
plot_model(x, plot = 'cluster') # Cluster Plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_999df" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_999df_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_999df_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_999df_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_999df_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_999df_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_999df_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_999df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_999df_row0_col0" class="data row0 col0" >0.6563</td>
#       <td id="T_999df_row0_col1" class="data row0 col1" >386.1793</td>
# ...

# %% [markdown]
# Checking for Clusters 3,4,5,6

# %%
setup(data = dataset, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)

print("For Cluster = 6")
x = create_model('meanshift', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_887eb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_887eb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_887eb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_887eb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_887eb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_887eb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_887eb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_887eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_887eb_row0_col0" class="data row0 col0" >0.6563</td>
#       <td id="T_887eb_row0_col1" class="data row0 col1" >386.1793</td>
# ...

# %% [markdown]
# KMC Using Transformation

# %%
setup(data = dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('meanshift')
plot_model(x, plot = 'cluster') # Cluster Plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_6d213" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d213_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6d213_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6d213_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6d213_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6d213_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6d213_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d213_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d213_row0_col0" class="data row0 col0" >0.6600</td>
#       <td id="T_6d213_row0_col1" class="data row0 col1" >1153.7177</td>
# ...

# %% [markdown]
# Checking for Clusters 3,4,5,6

# %%
setup(data = dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)

print("For Cluster = 6")
x = create_model('meanshift', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_cc541" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc541_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cc541_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cc541_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cc541_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cc541_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cc541_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc541_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc541_row0_col0" class="data row0 col0" >0.6600</td>
#       <td id="T_cc541_row0_col1" class="data row0 col1" >1153.7177</td>
# ...

# %% [markdown]
# KMC Using PCA

# %%
setup(data = dataset, pca = True, pca_method = 'linear', verbose=False)
x = create_model('meanshift')
plot_model(x, plot = 'cluster') # Cluster Plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_8324c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8324c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8324c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8324c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8324c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8324c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8324c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8324c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8324c_row0_col0" class="data row0 col0" >0.6223</td>
#       <td id="T_8324c_row0_col1" class="data row0 col1" >576.5206</td>
# ...

# %% [markdown]
# Checking for Clusters 3,4,5,6

# %%
setup(data = dataset, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)

print("For Cluster = 6")
x = create_model('meanshift', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_34b5d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34b5d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_34b5d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_34b5d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_34b5d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_34b5d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_34b5d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34b5d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34b5d_row0_col0" class="data row0 col0" >0.6223</td>
#       <td id="T_34b5d_row0_col1" class="data row0 col1" >576.5206</td>
# ...

# %% [markdown]
# KMC Using Transformation + Normalisation

# %%
setup(data = dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('meanshift')
plot_model(x, plot = 'cluster') # Cluster Plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ba4c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ba4c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9ba4c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9ba4c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9ba4c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9ba4c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9ba4c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ba4c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ba4c_row0_col0" class="data row0 col0" >0.6577</td>
#       <td id="T_9ba4c_row0_col1" class="data row0 col1" >391.8238</td>
# ...

# %% [markdown]
# Checking for Clusters 3,4,5,6

# %%
setup(data = dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)

print("For Cluster = 6")
x = create_model('meanshift', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c6745" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6745_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c6745_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c6745_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c6745_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c6745_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c6745_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6745_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6745_row0_col0" class="data row0 col0" >0.6577</td>
#       <td id="T_c6745_row0_col1" class="data row0 col1" >391.8238</td>
# ...

# %% [markdown]
# KMC Using Transformation + Normalisation

# %%
setup(data = dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear', verbose=False)
x = create_model('meanshift')
plot_model(x, plot = 'cluster') # Cluster Plot
# Out:
# <style type="text/css">
# </style>
# <table id="T_a0f93" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0f93_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a0f93_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a0f93_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a0f93_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a0f93_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a0f93_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0f93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0f93_row0_col0" class="data row0 col0" >0.6577</td>
#       <td id="T_a0f93_row0_col1" class="data row0 col1" >391.8238</td>
# ...

# %% [markdown]
# Checking for Clusters 3,4,5,6

# %%
setup(data = dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)

print("For Cluster = 6")
x = create_model('meanshift', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_9ddf6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ddf6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9ddf6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9ddf6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9ddf6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9ddf6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9ddf6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ddf6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ddf6_row0_col0" class="data row0 col0" >0.6577</td>
#       <td id="T_9ddf6_row0_col1" class="data row0 col1" >391.8238</td>
# ...
